# %%
# %%bash
# git add *
# git commit -m "Debug this shit."
# git push origin
# Out:
# [main 0643bc1] Debug this shit.
#  155 files changed, 5172 insertions(+), 331 deletions(-)
#  create mode 100644 GitHub.ipynb
#  create mode 100644 Glob 4 Meson.ipynb
#  create mode 100644 docs/html/dir_bfccd401955b95cf8c75461437045ac0.html
#  create mode 100644 docs/html/dir_bfccd401955b95cf8c75461437045ac0.js
#  create mode 100644 docs/html/functions_type.html
#  create mode 100644 docs/html/globals_defs.html
#  create mode 100644 docs/html/globals_type.html
#  create mode 100644 docs/html/inherit_graph_1.map
#  create mode 100644 docs/html/inherit_graph_1.md5
#  create mode 100644 docs/html/inherit_graph_1.png
#  create mode 100644 docs/html/inherit_graph_2.map
#  create mode 100644 docs/html/inherit_graph_2.md5
#  create mode 100644 docs/html/inherit_graph_2.png
#  create mode 100644 docs/html/inherit_graph_3.map
#  create mode 100644 docs/html/inherit_graph_3.md5
#  create mode 100644 docs/html/inherit_graph_3.png
#  create mode 100644 docs/html/inherit_graph_4.map
# ...
